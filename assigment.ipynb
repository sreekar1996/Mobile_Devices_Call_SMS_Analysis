# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("android_devices.csv")

# %%
df.columns=['Retail Branding', 'Marketing Name', 'device1', 'device']

# %%
len(df.device.unique())
# Out:
# 12883

# %%
len(df.Model.unique())
# Out:
# 12883

# %%
df.shape
# Out:
# (14546, 4)

# %%
df1=pd.read_excel("user_device and usage.xlsx",sheetname="user_device")

# %%
df1.head()
# Out:
#    use_id  user_id platform  platform_version     device  use_type_id
# 0   22782    26980      ios              10.2  iPhone7,2            2
# 1   22783    29628  android               6.0    Nexus 5            3
# 2   22784    28473  android               5.1   SM-G903F            1
# 3   22785    15200      ios              10.2  iPhone7,2            3
# 4   22786    28239  android               6.0  ONE E1003            1

# %%
df1.shape
# Out:
# (272, 6)

# %%
df1.device.unique()
# Out:
# array(['iPhone7,2', 'Nexus 5', 'SM-G903F', 'ONE E1003', 'GT-I9505',
#        'SM-G930F', 'D2303', 'iPhone6,2', 'SM-G361F', 'iPhone5,2',
#        'ONEPLUS A3003', 'SM-A300FU', 'SM-G935F', 'GT-I9195', 'A0001',
#        'SM-G900F', 'iPhone8,1', 'iPad3,1', 'HTC Desire 510',
#        'HTC One mini 2', 'iPhone9,4', 'GT-I8190N', 'D5803', 'E6653',
#        'SM-G920F', 'iPhone8,4', 'iPad2,4', 'SM-A310F', 'SM-N910F',
#        'SM-G360F', 'iPhone4,1', 'HTC One S', 'GT-I9300', 'SM-J320FN',
#        'HTC Desire 530', 'HTC Desire 825', 'F3111', 'SM-G800F',
#        'SM-N9005', 'Nexus 5X', 'iPhone9,3', 'SM-G925F', 'iPhone3,1',
#        'iPhone5,4', 'iPhone3,2', 'iPad4,5', 'iPad4,1', 'D6603', 'LG-H815',
#        'GT-I9515', 'EVA-L09', 'HTC One M9', 'GT-N7100', 'HTC Desire 626',
#        'Moto G (4)', 'ONE A2003', 'SM-A500FU', 'Lenovo K51c78', 'D5503',
#        'X11', 'HUAWEI VNS-L31', 'GT-I9506', 'HUAWEI CUN-L01', 'iPad5,3',
#        'MotoE2(4G-LTE)', 'C6603', 'HTC One_M8', 'iPhone7,1', 'VF-795',
#        'SM-G531F', 'HTC Desire 620', 'Vodafone Smart ultra 6'],
#       dtype=object)

# %%
df1.device.value_counts().head()
# Out:
# SM-G900F         32
# iPhone7,2        27
# iPhone6,2        22
# GT-I9505         13
# ONEPLUS A3003     9
# Name: device, dtype: int64

# %%
df2=pd.read_excel("user_device and usage.xlsx",sheetname="user_usage")

# %%
df2.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792

# %%
df2.shape
# Out:
# (240, 4)

# %%
user=pd.merge(df2,df1,how="left",on="use_id")

# %%
user.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0  12921.0  android               4.3  GT-I9505          1.0
# 1  28714.0  android               6.0  SM-G930F          1.0
# 2  28714.0  android               6.0  SM-G930F          1.0
# 3  29592.0  android               5.1     D2303          1.0
# 4  28217.0  android               5.1  SM-G361F          1.0

# %%
total=pd.merge(user,df,how="left",on="device")

# %%
total.head(300)
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# 5                      71.59                   79.26     1557.33   22793
# 6                      71.59                   79.26      519.12   22794
# 7                      71.59                   79.26      519.12   22795
# 8                      30.92                   22.77     3114.67   22799
# 9                      69.80                   14.70    25955.55   22801
# 10                    554.41                  150.06     3114.67   22804
# 11                    189.10                   24.08      519.12   22805
# 12                    283.30                  107.47    15573.33   22806
# 13                    324.34                   92.52      519.12   22808
# 14                    797.06                    7.67      519.12   22813
# 15                    797.06                    7.67      519.12   22813
# 16                    797.06                    7.67    15573.33   22814
# 25   29651.0  android               4.4  HTC One mini 2          1.0
# 26   29651.0  android               4.4  HTC One mini 2          1.0
# 27   29652.0  android               6.0        SM-G900F          1.0
# 28   28953.0  android               6.0        SM-G900F          1.0
# 29   29653.0      ios              10.1       iPhone7,2          2.0
# ..       ...      ...               ...             ...          ...
# 262      NaN      NaN               NaN             nan          NaN
# 263      NaN      NaN               NaN             nan          NaN
# 264      NaN      NaN               NaN             nan          NaN
# 265      NaN      NaN               NaN             nan          NaN
# 266      NaN      NaN               NaN             nan          NaN
# 267      NaN      NaN               NaN             nan          NaN
# 268      NaN      NaN               NaN             nan          NaN
# 269      NaN      NaN               NaN             nan          NaN
# 270      NaN      NaN               NaN             nan          NaN
# 271      NaN      NaN               NaN             nan          NaN
# 272      NaN      NaN               NaN             nan          NaN
# 273      NaN      NaN               NaN             nan          NaN
# 274      NaN      NaN               NaN             nan          NaN
# 275      NaN      NaN               NaN             nan          NaN
# 276      NaN      NaN               NaN             nan          NaN
# 277      NaN      NaN               NaN             nan          NaN
# 278      NaN      NaN               NaN             nan          NaN
# 279      NaN      NaN               NaN             nan          NaN
# 280      NaN      NaN               NaN             nan          NaN
# 281      NaN      NaN               NaN             nan          NaN
# 282      NaN      NaN               NaN             nan          NaN
# 283      NaN      NaN               NaN             nan          NaN
# 284      NaN      NaN               NaN             nan          NaN
# 285      NaN      NaN               NaN             nan          NaN
# 286      NaN      NaN               NaN             nan          NaN
# 287      NaN      NaN               NaN             nan          NaN
# 288      NaN      NaN               NaN             nan          NaN
# 289      NaN      NaN               NaN             nan          NaN
# 290      NaN      NaN               NaN             nan          NaN
# 291      NaN      NaN               NaN             nan          NaN
#
#            brand Retail Branding     Marketing Name         device1
# 0        samsung         Samsung          Galaxy S4           jflte
# 1        samsung         Samsung          Galaxy S7         herolte
# 2        samsung         Samsung          Galaxy S7         herolte
# 3    Other_Brand            Sony          Xperia M2           D2303
# 4        samsung         Samsung  Galaxy Core Prime  coreprimevelte
# 5        samsung         Samsung  Galaxy Core Prime  coreprimevelte
# 6        samsung         Samsung  Galaxy Core Prime  coreprimevelte
# 7        samsung         Samsung  Galaxy Core Prime  coreprimevelte
# 8     OnePlusOne             NaN                NaN             NaN
# 9        samsung         Samsung          Galaxy S4           jflte
# 10       samsung         Samsung     Galaxy S7 Edge        hero2lte
# 11       samsung         Samsung     Galaxy S4 Mini      serranolte
# 12    OnePlusOne         OnePlus        OnePlus One           A0001
# 13       samsung         Samsung          Galaxy S5            klte
# 14           HTC             HTC         Desire 510   htc_a11ul8x26
# 15           HTC             HTC     HTC Desire 510       htc_a11ul
# 16           HTC             HTC         Desire 510   htc_a11ul8x26
# 17           HTC             HTC     HTC Desire 510       htc_a11ul
# 18           HTC             HTC         Desire 510   htc_a11ul8x26
# 19           HTC             HTC     HTC Desire 510       htc_a11ul
# 20           HTC             HTC         Desire 510   htc_a11ul8x26
# 21           HTC             HTC     HTC Desire 510       htc_a11ul
# 22           HTC             HTC         Desire 510   htc_a11ul8x26
# 23           HTC             HTC     HTC Desire 510       htc_a11ul
# 24           HTC             HTC     HTC One mini 2       htc_memul
# 25           HTC             HTC     HTC One mini 2       htc_memul
# 26           HTC             HTC     HTC One mini 2       htc_memul
# 27       samsung         Samsung          Galaxy S5            klte
# 28       samsung         Samsung          Galaxy S5            klte
# 29        iphone             NaN                NaN             NaN
# ..           ...             ...                ...             ...
# 262  Other_Brand             NaN                NaN             NaN
# 263  Other_Brand             NaN                NaN             NaN
# 264  Other_Brand             NaN                NaN             NaN
# 265  Other_Brand             NaN                NaN             NaN
# 266  Other_Brand             NaN                NaN             NaN
# 267  Other_Brand             NaN                NaN             NaN
# 268  Other_Brand             NaN                NaN             NaN
# 269  Other_Brand             NaN                NaN             NaN
# 270  Other_Brand             NaN                NaN             NaN
# 271  Other_Brand             NaN                NaN             NaN
# 272  Other_Brand             NaN                NaN             NaN
# 273  Other_Brand             NaN                NaN             NaN
# 274  Other_Brand             NaN                NaN             NaN
# 275  Other_Brand             NaN                NaN             NaN
# 276  Other_Brand             NaN                NaN             NaN
# 277  Other_Brand             NaN                NaN             NaN
# 278  Other_Brand             NaN                NaN             NaN
# 279  Other_Brand             NaN                NaN             NaN
# 280  Other_Brand             NaN                NaN             NaN
# 281  Other_Brand             NaN                NaN             NaN
# 282  Other_Brand             NaN                NaN             NaN
# 283  Other_Brand             NaN                NaN             NaN
# 284  Other_Brand             NaN                NaN             NaN
# 285  Other_Brand             NaN                NaN             NaN
# 286  Other_Brand             NaN                NaN             NaN
# 287  Other_Brand             NaN                NaN             NaN
# 288  Other_Brand             NaN                NaN             NaN
# 289  Other_Brand             NaN                NaN             NaN
# 290  Other_Brand             NaN                NaN             NaN
# 291  Other_Brand             NaN                NaN             NaN
#
# [292 rows x 13 columns]

# %%
user.device.unique()
# Out:
# array(['GT-I9505', 'SM-G930F', 'D2303', 'SM-G361F', 'ONEPLUS A3003',
#        'SM-G935F', 'GT-I9195', 'A0001', 'SM-G900F', 'HTC Desire 510',
#        'HTC One mini 2', 'iPhone7,2', 'GT-I8190N', 'D5803', 'E6653',
#        'SM-A310F', 'SM-N910F', 'SM-G360F', 'HTC One S', 'GT-I9300',
#        'SM-J320FN', 'HTC Desire 530', 'HTC Desire 825', 'F3111',
#        'SM-G800F', 'SM-G920F', 'SM-N9005', 'Nexus 5X', 'SM-G925F',
#        'D6603', 'LG-H815', 'GT-I9515', 'EVA-L09', 'HTC One M9',
#        'SM-A300FU', 'GT-N7100', 'HTC Desire 626', 'Moto G (4)',
#        'ONE A2003', 'SM-A500FU', 'SM-G903F', 'Lenovo K51c78', 'D5503',
#        'X11', 'HUAWEI VNS-L31', 'GT-I9506', 'HUAWEI CUN-L01', 'iPhone6,2',
#        'MotoE2(4G-LTE)', 'C6603', 'HTC One_M8', 'VF-795', 'SM-G531F',
#        'HTC Desire 620', 'Vodafone Smart ultra 6', nan], dtype=object)

# %%
user.shape
# Out:
# (240, 9)

# %%
def first2(s):
    return s[:2]

# %%
d="sree"

# %%
first2(d)
# Out:
# 'sr'

# %%
#user["brand"]=user["device"].apply(lambda x: "samsung" if first2(x)=="GT" or first2(x)=="SM" else "lg")

# %%
def map(x):
    if(first2(x)=="GT" or first2(x)=="SM"):
        return("samsung")
    if(first2(x)=="iP"):
        return("iphone")
    if(first2(x)=="LG"):
        return("LG")
    if(first2(x)=="HT"):
        return("HTC")
    if(first2(x)=="Mo"):
        return("Motrolo")
    if(first2(x)=="ON" or first2(x)=="A0"):
        return("OnePlusOne")
    if(first2(x)=="HU"):
        return("HUAWAI")
    if(first2(x)=="Ne"):
        return("Nexus")
    if(first2(x)=="Le"):
        return("Lenovo")
    if(first2(x)=="D5" or first2(x)=="E6" or first2(x)=="C6" or first2(x)=="X1"):
        return("Sony_Xperia")
    else:
        return("Other_Brand")

# %%
map('SMadj')
# Out:
# 'samsung'

# %%
user.dtypes
# Out:
# outgoing_mins_per_month    float64
# outgoing_sms_per_month     float64
# monthly_mb                 float64
# use_id                       int64
# user_id                    float64
# platform                    object
# platform_version           float64
# device                      object
# use_type_id                float64
# brand                       object
# dtype: object

# %%
map('SMsd90')
# Out:
# 'samsung'

# %%
user["device"]=user["device"].astype("object")

# %%
user.dtypes
# Out:
# outgoing_mins_per_month    float64
# outgoing_sms_per_month     float64
# monthly_mb                 float64
# use_id                       int64
# user_id                    float64
# platform                    object
# platform_version           float64
# device                      object
# use_type_id                float64
# brand                       object
# dtype: object

# %%
user["brand"]=user["device"].apply(lambda x :map(x))

# %%
user.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id        brand
# 0  12921.0  android               4.3  GT-I9505          1.0      samsung
# 1  28714.0  android               6.0  SM-G930F          1.0      samsung
# 2  28714.0  android               6.0  SM-G930F          1.0      samsung
# 3  29592.0  android               5.1     D2303          1.0  Other_Brand
# 4  28217.0  android               5.1  SM-G361F          1.0      samsung

# %%
user.brand.value_counts()
# Out:
# samsung        99
# Other_Brand    92
# HTC            19
# OnePlusOne     11
# Sony_Xperia     7
# Motrolo         5
# HUAWAI          2
# iphone          2
# Nexus           1
# Lenovo          1
# LG              1
# Name: brand, dtype: int64

# %%
user["brand"].unique()
# Out:
# array(['samsung', 'Other_Brand', 'OnePlusOne', 'HTC', 'iphone',
#        'Sony_Xperia', 'Nexus', 'LG', 'Motrolo', 'Lenovo', 'HUAWAI'],
#       dtype=object)

# %%
user.groupby("platform")["outgoing_mins_per_month"].mean()
# Out:
# platform
# android    201.258535
# ios        366.060000
# Name: outgoing_mins_per_month, dtype: float64

# %%
user.groupby("platform")["outgoing_sms_per_month"].mean()
# Out:
# platform
# android     85.354586
# ios        293.975000
# Name: outgoing_sms_per_month, dtype: float64

# %%
user.groupby("platform")["monthly_mb"].mean()
# Out:
# platform
# android    4221.387834
# ios         961.155000
# Name: monthly_mb, dtype: float64

# %%
#people using iphones are most likely to send messages and calls

# %%
#people using androids are usiing more internet then ios people.

# %%
user["brand"].value_counts().plot(kind="barh")

# %%
user.groupby("brand")["outgoing_sms_per_month"].mean().plot(kind="barh")

# %%
user.groupby("brand")["outgoing_mins_per_month"].mean().plot(kind="barh")

# %%
user.groupby("brand")["monthly_mb"].mean().plot(kind="barh")

# %%
b=pd.read_csv("mtcars.csv")

# %%
b.head()
# Out:
#              CarName   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
b.am.value_counts()
# Out:
# 0    19
# 1    13
# Name: am, dtype: int64

# %%
pd.crosstab(b.am,b.cyl)
# Out:
# cyl  4  6   8
# am
# 0    3  4  12
# 1    8  3   2

# %%
sns.heatmap(b.corr())

# %%
pd.crosstab(b.am,b.cyl)
# Out:
# cyl  4  6   8
# am
# 0    3  4  12
# 1    8  3   2

# %%
 b.pivot_table(index='am',columns = 'cyl',values='mpg', aggfunc='mean')
# Out:
# cyl       4          6      8
# am
# 0    22.900  19.125000  15.05
# 1    28.075  20.566667  15.40
